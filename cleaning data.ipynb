# %%
import pandas as pd

# %%
df=pd.read_csv("hpi.csv",sep=",")
df
# Out:
#                id   Date  No of bedrooms  No of bathrooms  living area  \
# 0      6762810635  42491               4             2.50         2920
# 1      6762810998  42491               5             2.75         2910
# 2      6762812605  42491               4             2.50         3310
# 3      6762812919  42491               3             2.00         2710
# 4      6762813105  42491               3             2.50         2600
# ...           ...    ...             ...              ...          ...
# 10048  6762818676  42645               4             2.75         2440
# 10049  6762819138  42645               4             2.75         2630
# 10050  6762819907  42645               4             2.50         1850
# 10051  6762819919  42645               3             1.00         1500
# 10052  6762820847  42645               3             1.75         2290
#
#        lot area  No of floors  waterfront present  No of views  \
# ...

# %%
#FINDING NULL VLUES

df.isnull().sum().sum()
# Out:
# 17

# %%
#FILLING NULL VALUES WITH MEAN OF COLOUMN

df1=df.fillna(value=df['Built Year'].mean())
df1
# Out:
#                id   Date  No of bedrooms  No of bathrooms  living area  \
# 0      6762810635  42491               4             2.50         2920
# 1      6762810998  42491               5             2.75         2910
# 2      6762812605  42491               4             2.50         3310
# 3      6762812919  42491               3             2.00         2710
# 4      6762813105  42491               3             2.50         2600
# ...           ...    ...             ...              ...          ...
# 10048  6762818676  42645               4             2.75         2440
# 10049  6762819138  42645               4             2.75         2630
# 10050  6762819907  42645               4             2.50         1850
# 10051  6762819919  42645               3             1.00         1500
# 10052  6762820847  42645               3             1.75         2290
#
#        lot area  No of floors  waterfront present  No of views  \
# ...

# %%
#VISUALIZATION OF DATA
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)

# %%
HOUSEPRICESOFINDIA=pd.read_csv('hpi.csv')

# %%
HOUSEPRICESOFINDIA.head()
# Out:
#            id   Date  No of bedrooms  No of bathrooms  living area  lot area  \
# 0  6762810635  42491               4             2.50         2920      4000
# 1  6762810998  42491               5             2.75         2910      9480
# 2  6762812605  42491               4             2.50         3310     42998
# 3  6762812919  42491               3             2.00         2710      4500
# 4  6762813105  42491               3             2.50         2600      4750
#
#    No of floors  waterfront present  No of views  house condition  ...  \
# 0           1.5                 0.0          0.0              5.0  ...
# 1           1.5                 0.0          0.0              3.0  ...
# 2           2.0                 0.0          0.0              3.0  ...
# 3           1.5                 0.0          0.0              4.0  ...
# 4           1.0                 0.0          0.0              4.0  ...
#
#    Built Year  Renovation Year  Postal Code  Lattitude  Longitude  \
# ...

# %%
HOUSEPRICESOFINDIA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10053 entries, 0 to 10052
# Data columns (total 23 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              10053 non-null  int64
#  1   Date                            10053 non-null  int64
#  2   No of bedrooms                  10053 non-null  int64
#  3   No of bathrooms                 10053 non-null  float64
#  4   living area                     10053 non-null  int64
#  5   lot area                        10053 non-null  int64
#  6   No of floors                    10052 non-null  float64
#  7   waterfront present              10052 non-null  float64
#  8   No of views                     10052 non-null  float64
#  9   house condition                 10052 non-null  float64
#  10  house grade                     10052 non-null  float64
#  11  house area(excluding basement)  10052 non-null  float64
# ...

# %%
sns.displot(HOUSEPRICESOFINDIA['id'])

# %%
sns.pairplot(HOUSEPRICESOFINDIA[['No of floors','id','lot area']])
